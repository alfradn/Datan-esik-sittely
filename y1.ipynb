# %%
import matplotlib.pyplot as plt

plt.plot(alku_x)
plt.grid()
plt.title("Kiihtyvyys alussa")
plt.show()
plt.plot(keski_x)
plt.grid()
plt.title("Kiihtyvyys keskellä")
plt.show()
plt.plot(loppu_x)
plt.grid()
plt.title("Kiihtyvyys lopussa")
plt.show()

# %%
alku_x = acc_x[:1000]

loppu_x = acc_x[1000:]

keski_x = acc_x[100:3000]

# %%
import numpy as np
import pandas as pd

acc_x = numpy_acc_data[:,0]
osa_acc_x = acc_x[2500:2800]
min_x = np.min(osa_acc_x)
max_x = np.max(osa_acc_x)
mean_x = np.mean(osa_acc_x)
std_x = np.std(osa_acc_x)

print("Minimi:", round(min_x,2))
print("Maksimi:", round(max_x,2))
print("Keskiarvo:", round(mean_x,2))
print("Keskihajonta:", round(std_x,2))
# Out:
# Minimi: 9.73
# Maksimi: 9.84
# Keskiarvo: 9.79
# Keskihajonta: 0.02

# %%
print(numpy_acc_data[0])
print(numpy_acc_data[0][0])
print(numpy_acc_data[0,0])
print(numpy_acc_data[:,0])
# Out:
# [0.5743   9.753493 0.21536 ]
# 0.5743
# 0.5743
# [0.5743  0.88538 0.90931 ... 0.5743  0.88538 0.11486]

# %%
numpy_acc_data = acc_data.to_numpy()
print("Näytteiden määrä:",numpy_acc_data.size)
print("Datan muoto:", numpy_acc_data.shape)
print("Rivejä",numpy_acc_data.shape[0])
print("Sarakkeita",numpy_acc_data.shape[1])
# Out:
# Näytteiden määrä: 19248
# Datan muoto: (6416, 3)
# Rivejä 6416
# Sarakkeita 3

# %%
acc_data.plot(y=['AccX'],
               grid=True,
               title="kiihtyvyys X-akselilla",
               xlabel="Aika (s)",
               ylabel="kiihtyvyys (m/s^2)")
# Out:
# <Axes: title={'center': 'kiihtyvyys X-akselilla'}, xlabel='Aika (s)', ylabel='kiihtyvyys (m/s^2)'>

# %%
first_index = df.index[0]
df.index = df.index - first_index
df.index = df.index/1000

# %%
acc_data = df.drop(columns=['GyroX', 'GyroY', 'GyroZ'])
gyro_data = df.drop(columns=['AccX', 'AccY', 'AccZ'])

# %%
df = df.set_index('Timestamp')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#            Timestamp         AccX         AccY         AccZ        GyroX  \
# count    6416.000000  6416.000000  6416.000000  6416.000000  6416.000000
# mean   596209.045511     0.391286     0.409726     0.771724    -3.058708
# std     18759.487013     5.524986     5.847664     6.131751    50.201837
# min    563725.000000   -64.852592   -48.597572   -18.188494  -816.479980
# 25%    579966.500000     0.215360     0.119645     0.155539     0.350000
# 50%    596208.500000     0.574300     0.263220     0.253648     0.490000
# 75%    612451.500000     0.837520     0.909310     0.909310     0.560000
# max    628693.000000    21.828108    78.386887    78.401237   551.599976
#
#              GyroY        GyroZ
# count  6416.000000  6416.000000
# mean     -2.954696    -6.821141
# std      39.751570    52.363091
# min    -508.480011  -856.309998
# 25%      -4.550000     1.120000
# 50%      -4.410000     1.190000
# 75%      -4.340000     1.260000
# max     581.630005   552.720032

# %%
df.size
# Out:
# 44912

# %%
df.head(10)
# Out:
#    Timestamp     AccX      AccY     AccZ  GyroX  GyroY  GyroZ
# 0     563725  0.57430  9.753493  0.21536   0.35  -4.55   1.26
# 1     563734  0.88538  9.734350  0.47860   0.42  -4.62   1.33
# 2     563743  0.90931  9.784601  0.26322   0.56  -4.55   1.19
# 3     563752  0.98109  9.729565  0.43072   0.63  -4.69   1.12
# 4     563761  0.52644  9.751101  0.14357   0.49  -4.48   1.12
# 5     563770  0.78966  9.748708  0.35894   0.42  -4.55   1.19
# 6     563779  0.40679  9.746315  0.47860   0.49  -4.48   1.19
# 7     563788  0.71787  9.724778  0.23930   0.63  -4.55   1.19
# 8     563806  0.71787  9.734350  0.23929   0.70  -4.62   1.12
# 9     563816  0.59823  9.775029  0.95720   0.63  -4.62   1.12

# %%
df.columns
# Out:
# Index(['Timestamp', 'AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ'], dtype='object')

# %%
import pandas as pd
file_name = "kalibrointidata.csv"
df = pd.read_csv(file_name)

# %%
import numpy as np
import matplotlib as plt
import pandas as np
